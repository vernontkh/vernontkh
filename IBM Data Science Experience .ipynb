# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Vernon Tay Keat Hong**
# Pharmacist

# %% [markdown]
# _I am interested in data science because it helps increase efficiency in analysing data, to push the boundaries of healthcare, and to bring the benefits of the results we get through data analysis to the patients, helping people stay healthier for longer_

# %% [markdown]
# ### Cell 5 is supposed to print x, which is defined as 4+3+2+1

# %%
x=4+3+2+1
print(x)
# Out:
# 10

# %% [markdown]
# ***
# - First row of bulleted list
# - Second row of bulleted list
# - Third row of bulleted list
# ***
# 1. First row of numbered list
# 1. Second row of numbered list
# 1. Third row of numbered list
# ***
# | Multiplication of | 1 | 2 | 3 |
# | ----| ----| ----| ----|
# | 1 | 1 | 2 | 3 |
# | 2 | 2 | 4 | 6 |
# | 3 | 3 | 6 | 9 |
#
# ***
# ![alt text](https://static.boredpanda.com/blog/wp-content/uploads/2019/05/shiba-inu-dog-flower-fields-photography-masayo-ishizuki-japan-28-5cdbf3b7a5285__700.jpg "A friendly Shiba Inu for you")
# ***
# >To highlight, or not to highlight, that is the question
# ***
# To `highlight`, or ~~not to highlight~~, that is the question
